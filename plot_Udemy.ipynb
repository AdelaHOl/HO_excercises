# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5])
plt.show()

# %%
import numpy as np
from numpy.random import randn

fig = plt.figure()
a=fig.add_subplot(2,2,1)
b=fig.add_subplot(2,2,2)
c=fig.add_subplot(2,2,3)
plt.plot(randn(100).cumsum(),'r--')
a.hist(randn(10))
b.scatter(np.arange(20),np.arange(20)+5)
plt.show()

# %%
import numpy as np
from numpy.random import randn

# %%
fig = plt.figure()
a=fig.add_subplot(2,2,1)
b=fig.add_subplot(2,2,2)
c=fig.add_subplot(2,2,3)
plt.plot(randn(100).cumsum(),'r--')
a.hist(randn(10))
b.scatter(np.arange(20),np.arange(20)+5)
plt.show()

# %%
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
from pandas import Series
ser= Series(randn(10),index=np.arange(0,100,10))
ser.plot()
plt.show()

# %%
from pandas import DataFrame
df1= DataFrame(np.random.randn(10,4), columns=['a','b','c','d'],index=np.arange(10))
df1.plot()
plt.show()

# %%
data=Series(np.random.randn(16))
data.plot(kind='barh',color='k',alpha=0.5)
plt.show()
